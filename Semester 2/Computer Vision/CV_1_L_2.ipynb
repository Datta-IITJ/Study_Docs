# %%
# Python program to read image using OpenCV
from google.colab.patches import cv2_imshow 
# importing OpenCV(cv2) module
import cv2
 
# Save image in set directory
# Read RGB image
img = cv2.imread('brain.png')
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(gray_image[10,100])
 
# Output img with window name as 'image'
cv2_imshow(gray_image)
# Out:
# 21
# <PIL.Image.Image image mode=L size=1164x718 at 0x7F66897A9310>

# %%
import numpy as np
import random
def sp_noise(image,prob):
    '''
    Add salt and pepper noise to image
    prob: Probability of the noise
    '''
    output = np.zeros(image.shape,np.uint8)
    thres = 1 - prob 
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            rdn = random.random()
            if rdn < prob:
                output[i][j] = 0
            elif rdn > thres:
                output[i][j] = 255
            else:
                output[i][j] = image[i][j]
    return output

def gaussian_noise(image,mean,var):
      row,col,ch= image.shape
      output = np.zeros(image.shape,np.uint8)
      sigma = var**0.5
      gauss = np.random.normal(mean,sigma,(row,col,ch))
      gauss = gauss.reshape(row,col,ch)
      output = image + gauss
      return output

noise_img = sp_noise(img,0.01)
cv2_imshow(noise_img)
dst=cv.medianBlur(img,5)
cv2_imshow(dst)

#noise_img = gaussian_noise(img,50,500)
#cv2_imshow(noise_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1164x718 at 0x7FEFABC2C190>
# <PIL.Image.Image image mode=RGB size=1164x718 at 0x7FEFABC2C0A0>

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('brain.png')
kernel = np.ones((10,10),np.float32)/25
dst = cv.filter2D(img,-1,kernel)
dst=cv.medianBlur(img,5)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()
